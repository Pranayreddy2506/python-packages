# %%
# !pip install matplotlib

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.8.4

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt  #We can use both

# %%
x = [2,4,6,8,10,12,14,32,33]
y = [1,3,5,7,9,11,13,20,23]
plt.plot(x,y)
plt.show()

# %%
#Bar chart
x = [1,3,5,7,9,11,13]
y = [2,4,6,8,10,12,14]
plt.bar(x,y)
plt.title("Bar Chart")
plt.show()

# %%
# Histogram chart
y = [1,23,43,46,51,54,67,74]
plt.hist(y)
plt.title("Histogram")
plt.show()

# %%
#Scatter plot
x = [1,3,5,7,9,11,13,15,21,23,43]
y = [2,4,6,8,10,12,14,16,18,24,41]
plt.scatter(x,y)
plt.title("Scatter Plot")
plt.show()

# %%
# Pie chart
from matplotlib import pyplot as plt
labels = ['Lokesh','Kittu','Vasu']
score = [50, 30, 20]
plt.pie(marks, labels = labels, autopct = '%1.1f%%', startangle = 180)
plt.title("Pie Chart")
plt.show()

# %%
#Area plot
x = [1, 2, 3, 4, 5]
y1, y2 = [10, 20, 15, 25, 30], [5, 15, 10, 20, 25]

# Area Chart
plt.fill_between(x, y1, y2, color='skyblue', alpha=0.4, label='Area 1-2')
plt.plot(x, y1, label='Line 1', marker='o')
plt.plot(x, y2, label='Line 2', marker='o')

# Labels and Title
plt.xlabel('X-axis'), plt.ylabel('Y-axis'), plt.title('Area Chart Example')

# Legend and Display
plt.legend(), plt.show()
# Out:
# (<matplotlib.legend.Legend at 0x29ebc273f20>, None)
